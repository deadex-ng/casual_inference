# %% [markdown]
# <h1 align='center'>## Data Exploration</h1>

# %% [markdown]
# ![Cancer-process.png](attachment:Cancer-process.png)

# %% [markdown]
# You can extract the data from [kaggle](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data) or from [UCI Machine Learning Repository](https://archive-beta.ics.uci.edu/ml/datasets?name=breast). In the latter you can find even more data that you may explore further. To understand more about the data, and how it is collected we highly recommend reading this paper:[(PDF)
# Breast Cancer Diagnosis and Prognosis Via Linear Programming (researchgate.net)](https://www.researchgate.net/publication/2302195_Breast_Cancer_Diagnosis_and_Prognosis_Via_Linear_Programming#pf1).
#
# Features in the data are computed from a digitized image of a fine needle aspirate (FNA)
# of a breast mass.
#
# Attribute Information:
#
#     1. ID number
#     2. Diagnosis (M = malignant, B = benign)
#     3. The remaining (3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# 1. radius (mean of distances from center to points on the perimeter)
# 2. texture (standard deviation of gray-scale values)
# 3.  Perimeter
# 4.  Area
# 5. smoothness (local variation in radius lengths)
# 6. compactness (perimeter^2 / area - 1.0)
# 7. concavity (severity of concave portions of the contour)
# 8. concave points (number of concave portions of the contour)
# 9. Symmetryj) fractal dimension ("coastline approximation" - 1)

# %%
#pip install -U kaleido

# %%
import sys
import logging
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs
import plotly.express as px
import plotly.io as pio

from sklearn import preprocessing
pio.renderers.default = "svg"
# %matplotlib inline

# %%
sys.path.append('../scripts')

# %%
from feature_viz import VisualizeFeature

visualize = VisualizeFeature()

# %%
logging.info('Loading data sets')

df = pd.read_csv(r"..\data\data.csv")

logging.info('Loading data sets done.')

# %%
print("In total: ", df.shape)  # In total:  (1017209, 8)
# Out:
# In total:  (569, 33)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop('Unnamed: 32',axis=1,inplace=True)

# %%
print("\nNull Values:\n", df.isnull().sum())
print("\nMissing Values:\n", df.isna().sum())
# Out:
# Null Values:
#  id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#df_mean = df[df.columns[:11]]
#df_mean

df_mean = df [['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean'
          ,'concave points_mean','symmetry_mean','fractal_dimension_mean']]

#x = df_mean.values
#min_max_scaler = preprocessing.MinMaxScaler()
#x_scaled = min_max_scaler.fit_transform(x)

#df_mean = pd.DataFrame(x_scaled)

#normalize data frame
df_mean = (df_mean - df_mean.mean())/df_mean.std()

#add diagnosis column
df_mean = df_mean.join(df['diagnosis'])
df_mean
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.096100     -2.071512        1.268817   0.983510         1.567087
# 1       1.828212     -0.353322        1.684473   1.907030        -0.826235
# 2       1.578499      0.455786        1.565126   1.557513         0.941382
# 3      -0.768233      0.253509       -0.592166  -0.763792         3.280667
# 4       1.748758     -1.150804        1.775011   1.824624         0.280125
# ..           ...           ...             ...        ...              ...
# 564     2.109139      0.720838        2.058974   2.341795         1.040926
# 565     1.703356      2.083301        1.614511   1.722326         0.102368
# 566     0.701667      2.043775        0.672084   0.577445        -0.839745
# 567     1.836725      2.334403        1.980781   1.733693         1.524426
# 568    -1.806811      1.220718       -1.812793  -1.346604        -3.109349
#
# ...

# %%
df_se = df [['radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se'
          ,'concave points_se','symmetry_se','fractal_dimension_se']]

#normalize data frame
df_se = (df_se - df_se.mean())/df_se.std()

#add diagnosis column
df_se = df_se.join(df['diagnosis'])
df_se
# Out:
#      radius_se  texture_se  perimeter_se   area_se  smoothness_se  \
# 0     2.487545   -0.564768      2.830540  2.485391      -0.213814
# 1     0.498816   -0.875473      0.263095  0.741749      -0.604819
# 2     1.227596   -0.779398      0.850180  1.180298      -0.296744
# 3     0.326087   -0.110312      0.286341 -0.288125       0.689095
# 4     1.269426   -0.789549      1.272070  1.189310       1.481763
# ..         ...         ...           ...       ...            ...
# 564   2.779634    0.070963      2.377491  2.601897       1.085429
# 565   1.299356    2.258951      1.155840  1.290429      -0.423637
# 566   0.184730   -0.257145      0.276450  0.180539      -0.379008
# 567   1.156917    0.685485      1.437265  1.008615      -0.172848
# 568  -0.070217    0.382756     -0.157311 -0.465742       0.049299
#
#      compactness_se  concavity_se  concave points_se  symmetry_se  \
# 0          1.315704      0.723390           0.660239     1.147747
# ...

# %%
df_worst = df[['radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst'
               ,'concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']]
#normalize data frame
df_worst = (df_worst - df_worst.mean())/df_worst.std()

#add diagnosis column
df_worst = df_worst.join(df['diagnosis'])

df_worst
# Out:
#      radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0        1.885031      -1.358098         2.301575    1.999478
# 1        1.804340      -0.368879         1.533776    1.888827
# 2        1.510541      -0.023953         1.346291    1.455004
# 3       -0.281217       0.133866        -0.249720   -0.549538
# 4        1.297434      -1.465481         1.337363    1.219651
# ..            ...            ...              ...         ...
# 564      1.899514       0.117596         1.751022    2.013529
# 565      1.535369       2.045599         1.420690    1.493644
# 566      0.560868       1.373645         0.578492    0.427529
# 567      1.959515       2.235958         2.301575    1.651717
# 568     -1.409652       0.763518        -1.431475   -1.074867
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0            1.306537           2.614365         2.107672
# 1           -0.375282          -0.430066        -0.146620
# ...

# %%
dfg = df.groupby(['diagnosis']).count().reset_index()
fig = px.bar(dfg,x = dfg.diagnosis,color =dfg.diagnosis, y='id',title='Tumor Distribution')
y = df.diagnosis
B,M = y.value_counts()
print( 'Number of Benign Tumors ', B)
print( 'Number of Malignant Tumors ', M)
fig.show()
# Out:
# Number of Benign Tumors  357
# Number of Malignant Tumors  212

# %% [markdown]
# The number of maligant is 357 while benign 212. The numbers are not balancing

# %%
#correlation of mean features with diagnosis
df_mean['diagnosis'] = df_mean['diagnosis'].astype('category').cat.codes
df_mean.drop('diagnosis',axis=1).corrwith(df_mean.diagnosis)
# Out:
# radius_mean               0.730029
# texture_mean              0.415185
# perimeter_mean            0.742636
# area_mean                 0.708984
# smoothness_mean           0.358560
# compactness_mean          0.596534
# concavity_mean            0.696360
# concave points_mean       0.776614
# symmetry_mean             0.330499
# fractal_dimension_mean   -0.012838
# dtype: float64

# %%
fig = px.bar(df_mean.drop('diagnosis',axis=1).corrwith(df_mean.diagnosis),title='Correlation of Mean Features with Diagnosis')
fig.show()

# %% [markdown]
# - fractual_dimension_mean is the feature that least correlates with diagnosis
# - All the other mean features show a significant correlation with the diagnosis

# %%
#correlation of worst error features with diagnosis
df_worst['diagnosis'] = df_worst['diagnosis'].astype('category').cat.codes
df_worst.drop('diagnosis',axis=1).corrwith(df_worst.diagnosis)
# Out:
# radius_worst               0.776454
# texture_worst              0.456903
# perimeter_worst            0.782914
# area_worst                 0.733825
# smoothness_worst           0.421465
# compactness_worst          0.590998
# concavity_worst            0.659610
# concave points_worst       0.793566
# symmetry_worst             0.416294
# fractal_dimension_worst    0.323872
# dtype: float64

# %%
fig = px.bar(df_worst.drop('diagnosis',axis=1).corrwith(df_worst.diagnosis),title='Correlation of Worst Error Features with Diagnosis')
fig.show()

# %% [markdown]
# - All the worst features show a significant correlation with the diagnosis

# %%
#correlation of mean features with diagnosis
df_se['diagnosis'] = df_se['diagnosis'].astype('category').cat.codes
df_se.drop('diagnosis',axis=1).corrwith(df_se.diagnosis)
# Out:
# radius_se               0.567134
# texture_se             -0.008303
# perimeter_se            0.556141
# area_se                 0.548236
# smoothness_se          -0.067016
# compactness_se          0.292999
# concavity_se            0.253730
# concave points_se       0.408042
# symmetry_se            -0.006522
# fractal_dimension_se    0.077972
# dtype: float64

# %%
#correlation of mean features with diagnosis
df_se['diagnosis'] = df_se['diagnosis'].astype('category').cat.codes
df_se.drop('diagnosis',axis=1).corrwith(df_se.diagnosis)
# Out:
# radius_se               0.567134
# texture_se             -0.008303
# perimeter_se            0.556141
# area_se                 0.548236
# smoothness_se          -0.067016
# compactness_se          0.292999
# concavity_se            0.253730
# concave points_se       0.408042
# symmetry_se            -0.006522
# fractal_dimension_se    0.077972
# dtype: float64

# %%
fig = px.bar(df_se.drop('diagnosis',axis=1).corrwith(df_se.diagnosis),title='Correlation of Squared Error Features with Diagnosis')
fig.show()

# %% [markdown]
# - texture_se, smoothness_se and symetry_se are least correlated with the diagnosis
# - The rest of the features have a significant

# %%
corr_matrix = df.corr()  # Correlation Matrix

# Mask for Heatmap
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(corr_matrix)] = True

#YlGn
# Correlation Matrix Heatmap including all features
fig, ax = plt.subplots(figsize=(22, 10))
ax = sns.heatmap(corr_matrix, mask=mask, annot=True, linewidths=0.5, fmt=".2f", cmap="Blues");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5);
ax.set_title("Correlation Matrix Heatmap including all features")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap including all features')

# %%
df_mean
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.096100     -2.071512        1.268817   0.983510         1.567087
# 1       1.828212     -0.353322        1.684473   1.907030        -0.826235
# 2       1.578499      0.455786        1.565126   1.557513         0.941382
# 3      -0.768233      0.253509       -0.592166  -0.763792         3.280667
# 4       1.748758     -1.150804        1.775011   1.824624         0.280125
# ..           ...           ...             ...        ...              ...
# 564     2.109139      0.720838        2.058974   2.341795         1.040926
# 565     1.703356      2.083301        1.614511   1.722326         0.102368
# 566     0.701667      2.043775        0.672084   0.577445        -0.839745
# 567     1.836725      2.334403        1.980781   1.733693         1.524426
# 568    -1.806811      1.220718       -1.812793  -1.346604        -3.109349
#
# ...

# %%
#data3 = pd.melt( df_mean, id_vars = 'diagnosis', 
#               var_name = 'features', 
#               value_name = 'value' )
#data3

# %%
#fig = px.violin(df_mean,x=df['radius_mean'],color='diagnosis',violinmode='overlay')
#fig = px.violin(data3,x='features',y= 'value', color='diagnosis',hover_data=data3.columns)
#fig.show()

# %% [markdown]
# ## mean features  vs diagnosis

# %%
#plotly express does not have the functionality for ploting sbuplots so that is why I have
#looped throught the clomns to generata plot for each
for x in ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean',
         'concave points_mean','symmetry_mean']:
    fig = px.histogram(df_mean, x=x, color="diagnosis", marginal="box",
                   hover_data=df_mean.columns)
    fig.show()

# %% [markdown]
# ## worst features  vs diagnosis

# %%
for x in ['radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst',
          'concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']:
    fig = px.histogram(df_worst, x=x, color="diagnosis", marginal="box",
                   hover_data=df_worst.columns)
    fig.show()

# %% [markdown]
# ## squared error features  vs diagnosis

# %%
for x in ['radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se',
          'concave points_se','symmetry_se','fractal_dimension_se']:
    fig = px.histogram(df_se, x=x, color="diagnosis", marginal="box",
                   hover_data=df_se.columns)
    fig.show()

# %%
#plotly express does not have the functionality for ploting sbuplots so that is why I have
#looped throught the clomns to generata plot for each
mean_list= ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean',
         'concave points_mean','symmetry_mean']
visualize.histplot(df_mean,mean_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-f256962f924a> in <module>
#       3 mean_list= ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean',
#       4          'concave points_mean','symmetry_mean']
# ----> 5 visualize.histplot(df_mean,mean_list)
#
# ~\Desktop\week7git\casual_inference\scripts\feature_viz.py in histplot(self, df, col_list)
#      17
#      18         for x in col_list:
# ---> 19             fig = px.histogram(df, x=x, color="diagnosis", marginal="box",hover_data=df.columns)
#      20
#      21             fig.show()
#
# NameError: name 'df_worst' is not defined

# %%
df_mean.to_csv(r'../data/mean_features.csv')

# %%
df_worst.to_csv(r'../data/worst_features.csv')

# %%
import sys 
sys.path.append('../scripts')

# %%
from feature_viz import VisualizeFeature

visualize = VisualizeFeature()
